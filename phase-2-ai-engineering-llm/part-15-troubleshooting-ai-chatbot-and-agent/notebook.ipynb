# %% [markdown]
# # Troubleshooting AI Chatbot and Agent — PT Kirimin

# %%
def diagnose(trace):
    if trace.get('policy_violation'): return 'kill_switch_and_human_review'
    if not trace.get('retrieved_ids'): return 'retrieval_investigation'
    if not trace.get('schema_valid'): return 'output_validator_investigation'
    if trace.get('provider_error'): return 'provider_fallback'
    return 'generation_quality_investigation'
traces=[{'retrieved_ids':[]},{'retrieved_ids':['SOP-1'],'schema_valid':False},{'provider_error':True}]
[diagnose(t) for t in traces]

# %% [markdown]
# ## Mini-exercise
# Buat sanitized reproduction record dan corrective action untuk SOP stale.
# # TODO: tulis incident timeline.

# %% [markdown]
# ## Takeaway
# Troubleshooting AI membutuhkan stage trace, policy awareness, rollback, dan regression test.
