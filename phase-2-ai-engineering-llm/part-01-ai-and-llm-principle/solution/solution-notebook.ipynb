# %% [markdown]
# # Solution — AI and LLM Principle

# %%
def decision(question):
    sensitive=any(word in question.lower() for word in ['refund','account','data pribadi'])
    return {'route':'human_review' if sensitive else 'rag_faq','reason':'policy boundary' if sensitive else 'routine question'}
decision('Bagaimana cek status kiriman?'), decision('Minta refund')

# %% [markdown]
# Routing policy membatasi domain berisiko sebelum model menghasilkan jawaban final.
