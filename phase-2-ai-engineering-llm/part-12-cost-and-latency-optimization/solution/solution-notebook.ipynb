# %% [markdown]
# # Solution — Cost and Latency

# %%
def cache_key(question, prompt_version, sop_version, access_scope):
    return '|'.join([question,prompt_version,sop_version,access_scope])
cache_key('status','p2','sop7','support')

# %% [markdown]
# Version dan access scope menjadi bagian key agar cache tidak melewati boundary keamanan atau freshness.
