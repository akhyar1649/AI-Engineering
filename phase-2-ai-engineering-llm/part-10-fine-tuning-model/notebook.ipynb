# %% [markdown]
# # Fine-Tuning Model — PT Kirimin
# Kita memeriksa dataset dan decision gate sebelum training.

# %%
cases=[{'id':i,'input':f'pertanyaan {i}','label':'tracking' if i%2==0 else 'faq'} for i in range(10)]
train=cases[:6]; validation=cases[6:8]; test=cases[8:]
len(train),len(validation),len(test),set(x['id'] for x in train)&set(x['id'] for x in test)

# %%
decision={'baseline_accuracy':0.82,'target_gain':0.05,'knowledge_changes_daily':True,'recommendation':'improve RAG first' if True else 'fine-tune'}
decision

# %% [markdown]
# ## Mini-exercise
# Tambahkan PII scan dan duplicate detection. Buat matrix kapan prompt, RAG, atau fine-tune dipilih.
# # TODO: lengkapi decision gate.

# %% [markdown]
# ## Takeaway
# Fine-tuning adalah experiment terkontrol dengan dataset, baseline, evaluation, dan rollback.
