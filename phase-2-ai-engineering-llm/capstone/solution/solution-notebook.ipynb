# %% [markdown]
# # Capstone 2 Reference Checks

# %%
cases=[('faq',False,True),('refund',True,False),('unknown',False,False)]
def expected(category,needs_human,evidence):
    if category=='refund': return 'human_review'
    if not evidence: return 'abstain'
    return 'answer'
[expected(*case) for case in cases]

# %% [markdown]
# Reference checks memastikan policy boundary diuji bersama happy path.
