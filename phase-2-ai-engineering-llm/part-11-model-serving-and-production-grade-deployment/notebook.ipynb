# %% [markdown]
# # Model Serving & Production-Grade Deployment — PT Kirimin

# %%
def route(request):
    if request['risk']=='high': return 'human_review'
    if request['tokens']>4000: return 'long_context_model'
    return 'fast_model'
requests=[{'risk':'low','tokens':500},{'risk':'high','tokens':200},{'risk':'low','tokens':5000}]
[route(r) for r in requests]

# %% [markdown]
# ## Mini-exercise
# Tambahkan concurrency limit, timeout budget, and canary percentage.
# # TODO: lengkapi serving policy.

# %% [markdown]
# ## Takeaway
# Production serving adalah sistem dengan resource, policy, telemetry, dan rollback, bukan sekadar endpoint model.
