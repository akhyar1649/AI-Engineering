# %% [markdown]
# # RAG Optimization & Troubleshooting — PT Kirimin

# %%
relevant={'SOP-1','SOP-3'}
retrieved=['SOP-2','SOP-1','SOP-4']
precision=len(set(retrieved)&relevant)/len(retrieved)
recall=len(set(retrieved)&relevant)/len(relevant)
{'precision':precision,'recall':recall,'mrr':1/(retrieved.index('SOP-1')+1)}

# %%
for k in [1,2,3]:
    selected=retrieved[:k]
    print(k, len(set(selected)&relevant)/k, len(set(selected)&relevant)/len(relevant))

# %% [markdown]
# ## Mini-exercise
# Buat kasus ketika top-k lebih besar menaikkan recall tetapi menurunkan precision dan menambah token.
# # TODO: tulis diagnosis.

# %% [markdown]
# ## Takeaway
# Optimasi RAG harus berbasis stage-level measurement dan regression set.
