# %% [markdown]
# # Solution — AI Risk Governance

# %%
controls={'faq':{'action':'answer','evidence':'citation'},'account':{'action':'human_review','evidence':'handoff_id'},'refund':{'action':'blocked','evidence':'policy_event'}}
controls

# %% [markdown]
# Policy table membuat boundary dapat diuji dan direview, bukan hanya menjadi teks umum.
