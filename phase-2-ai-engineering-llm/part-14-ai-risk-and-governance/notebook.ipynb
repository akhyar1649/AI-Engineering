# %% [markdown]
# # AI Risk and Governance — PT Kirimin

# %%
risks=[{'name':'wrong_refund_advice','impact':5,'likelihood':3,'control':'human_review'},{'name':'stale_sop','impact':3,'likelihood':4,'control':'freshness_check'},{'name':'pii_leak','impact':5,'likelihood':2,'control':'redaction_access_filter'}]
[(r['name'],r['impact']*r['likelihood']) for r in risks]

# %%
def route_risk(category):
    return 'blocked' if category=='prohibited' else ('human_review' if category=='review_required' else 'automated_faq')
[route_risk(x) for x in ['allowed','review_required','prohibited']]

# %% [markdown]
# ## Mini-exercise
# Tambahkan owner, residual risk, evidence, dan review date pada risk register.
# # TODO: lengkapi governance artifact.

# %% [markdown]
# ## Takeaway
# Risk governance menerjemahkan nilai abstrak menjadi boundary, owner, control, dan evidence.
