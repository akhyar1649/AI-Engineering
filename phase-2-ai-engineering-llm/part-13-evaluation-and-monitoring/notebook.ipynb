# %% [markdown]
# # Evaluation and Monitoring — PT Kirimin

# %%
traces=[{'case':'faq','grounded':1,'relevant':1,'latency_ms':800,'escalated':0},{'case':'no_evidence','grounded':1,'relevant':1,'latency_ms':1200,'escalated':1},{'case':'faq','grounded':0,'relevant':1,'latency_ms':900,'escalated':0}]
grounded=sum(t['grounded'] for t in traces)/len(traces)
p95=sorted(t['latency_ms'] for t in traces)[-1]
{'grounded_rate':grounded,'p95_latency_ms':p95,'alert':grounded<0.9 or p95>2000}

# %% [markdown]
# ## Mini-exercise
# Tambahkan feedback user, prompt/model version, dan drift comparison.
# # TODO: buat alert routing.

# %% [markdown]
# ## Takeaway
# Evaluasi dan monitoring menghubungkan kualitas AI dengan keputusan release dan operasi.
