# %% [markdown]
# # Solution — Evaluation and Monitoring

# %%
def redact(text):
    return text.replace('08123456789','[PHONE]').replace('customer@example.com','[EMAIL]')
redact('hubungi 08123456789 atau customer@example.com')

# %% [markdown]
# Redaction sebelum trace export mengurangi risiko observability menjadi sumber data sensitif baru.
