# %% [markdown]
# # Consuming and Presenting AI Output — PT Kirimin

# %%
response={'schema_version':'1','answer':'Status shipment sedang in transit.','citations':[{'id':'TRACK-7','label':'tracking event'}],'confidence':'supported','needs_human':False,'reason_code':None}
def render(data):
    return {'message':data['answer'],'sources':[c['label'] for c in data['citations']],'show_escalate':data['needs_human']}
render(response)

# %% [markdown]
# ## Mini-exercise
# Tambahkan error response versioned dan state partial untuk streaming.
# # TODO: lengkapi API contract.

# %% [markdown]
# ## Takeaway
# Presentasi output adalah bagian dari safety dan product design, bukan pekerjaan kosmetik.
