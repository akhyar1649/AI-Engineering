# %% [markdown]
# # Solution — AI Output Contract

# %%
def public_response(internal):
    return {'schema_version':'1','answer':internal.get('answer'), 'citations':internal.get('citations',[]), 'needs_human':internal.get('needs_human',True), 'reason_code':internal.get('reason_code')}
public_response({'answer':'x','citations':['SOP-1'],'needs_human':False,'internal_prompt':'secret'})

# %% [markdown]
# Projection eksplisit mencegah field internal ikut keluar ke consumer.
