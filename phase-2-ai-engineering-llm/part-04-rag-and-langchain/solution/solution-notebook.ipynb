# %% [markdown]
# # Solution — RAG and LangChain

# %%
def answer(question, docs):
    if not docs: return {'answer':'Saya belum menemukan SOP yang relevan.','citations':[],'needs_human':True}
    return {'answer':docs[0]['text'],'citations':[docs[0]['id']],'needs_human':False}
answer('status',[]), answer('alamat',[{'id':'SOP-12','text':'Hanya sebelum pickup.'}])

# %% [markdown]
# Abstention adalah output valid, bukan failure, ketika evidence tidak cukup.
