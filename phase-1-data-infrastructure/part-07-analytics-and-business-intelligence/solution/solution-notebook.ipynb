# %% [markdown]
# # Solution — Analytics and Business Intelligence

# %%
import pandas as pd
df=pd.DataFrame({'city':['Jakarta','Bandung'],'eligible_orders':[100,80],'delivered_orders':[92,68]})
df['delivery_success_rate']=df['delivered_orders']/df['eligible_orders']
df['freshness_at']='2026-09-18T06:30:00+07:00'
df['definition_version']='delivery_success_v1'
df

# %% [markdown]
# Aggregate global harus memakai total delivered dibagi total eligible, bukan rata-rata sederhana dari rate kota.
