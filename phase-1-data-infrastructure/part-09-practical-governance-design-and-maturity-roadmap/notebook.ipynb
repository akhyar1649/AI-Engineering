# %% [markdown]
# # Practical Governance Design — PT Kirimin

# %%
import pandas as pd
raci = pd.DataFrame([
    {'activity': 'approve_order_schema', 'responsible': 'Data Engineer', 'accountable': 'Dinda', 'consulted': 'Reza', 'informed': 'Sari'},
    {'activity': 'approve_delivery_metric', 'responsible': 'Analytics Engineer', 'accountable': 'Sari', 'consulted': 'Dinda', 'informed': 'Fajar'},
])
raci

# %%
evidence = {'owner_assigned': 1, 'quality_checks_automated': 0, 'lineage_documented': 0, 'incident_sla': 0}
score = sum(evidence.values()) / len(evidence)
{'score': score, 'next_action': 'automate quality checks' if score < 0.5 else 'measure SLO'}

# %% [markdown]
# ## Mini-exercise
# Tambahkan evidence untuk domain customer ticket dan pilih satu milestone 30 hari.
# # TODO: lengkapi roadmap.

# %% [markdown]
# ## Takeaway
# Roadmap governance harus menyebut tindakan, owner, evidence, dan outcome bisnis.
