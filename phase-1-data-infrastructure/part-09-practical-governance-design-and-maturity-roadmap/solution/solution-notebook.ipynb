# %% [markdown]
# # Solution — Governance Roadmap

# %%
milestones=[{'days':30,'deliverable':'domain inventory','owner':'Dinda','measure':'100% critical fields have owner'},{'days':60,'deliverable':'automated checks','owner':'Data Engineering','measure':'blocking checks run daily'},{'days':90,'deliverable':'contract review','owner':'Reza','measure':'breaking changes require approval'}]
milestones

# %% [markdown]
# Roadmap solution menyertakan evidence sehingga progress dapat diaudit.
