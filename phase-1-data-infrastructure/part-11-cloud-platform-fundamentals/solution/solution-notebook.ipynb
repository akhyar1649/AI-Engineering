# %% [markdown]
# # Solution — Cloud Fundamentals

# %%
roles={'ingestion':['object_storage:write','source:read'],'transform':['object_storage:read','warehouse:write'],'analyst':['warehouse:read']}
roles

# %% [markdown]
# Role matrix memberi akses berdasarkan task dan dapat dibandingkan dengan policy provider sebelum deployment.
