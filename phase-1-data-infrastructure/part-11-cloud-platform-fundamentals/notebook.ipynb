# %% [markdown]
# # Cloud Platform Fundamentals — PT Kirimin

# %%
services = [
    {'need': 'raw files', 'choice': 'object storage', 'cost_driver': 'GB-month + requests', 'control': 'lifecycle policy'},
    {'need': 'API', 'choice': 'container compute', 'cost_driver': 'CPU-hours', 'control': 'autoscaling ceiling'},
    {'need': 'serving SQL', 'choice': 'managed PostgreSQL', 'cost_driver': 'instance + storage + I/O', 'control': 'backup retention'},
]
services

# %%
monthly = {'object_storage_gb': 500, 'compute_hours': 720, 'db_hours': 720}
assumptions = {'storage_per_gb': 0.02, 'compute_per_hour': 0.04, 'db_per_hour': 0.12}
monthly['object_storage_gb'] * assumptions['storage_per_gb'] + monthly['compute_hours'] * assumptions['compute_per_hour'] + monthly['db_hours'] * assumptions['db_per_hour']

# %% [markdown]
# ## Mini-exercise
# Tambahkan biaya egress dan sensitivity jika volume naik 3x.
# # TODO: lengkapi cost model.

# %% [markdown]
# ## Takeaway
# Cloud decision menggabungkan workload, reliability, security, dan biaya; bukan sekadar memilih provider.
