# %% [markdown]
# # Solution — NoSQL Concepts

# %%
def partition_key(event):
    return f"{event['city']}:{event['event_time'][:13]}"
sample={'city':'Jakarta','event_time':'2026-09-18T10:20:00+07:00'}
partition_key(sample)

# %% [markdown]
# Bucket waktu membantu membatasi hot key, tetapi query lintas waktu harus membaca beberapa bucket.
