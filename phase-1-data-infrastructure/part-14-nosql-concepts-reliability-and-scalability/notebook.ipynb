# %% [markdown]
# # NoSQL Concepts — PT Kirimin

# %% [markdown]
# > Diverifikasi: MongoDB v8.3 series — sumber: https://www.mongodb.com/docs/manual/release-notes/ — tanggal cek: 2026-09-18

# %%
events=[{'shipment_id':'S-1','city':'Jakarta'},{'shipment_id':'S-2','city':'Jakarta'},{'shipment_id':'S-3','city':'Bandung'}]
from collections import Counter
counts=Counter(event['city'] for event in events)
counts

# %% [markdown]
# Jika partition key hanya `city`, Jakarta dapat menjadi hot key. Kombinasikan dengan bucket waktu atau hash sesuai query dan retention.

# %% [markdown]
# ## Mini-exercise
# Bandingkan key `shipment_id`, `city`, dan `(city, hour_bucket)` untuk tiga access pattern.
# # TODO: tulis trade-off.

# %% [markdown]
# ## Takeaway
# Model NoSQL harus diturunkan dari access pattern dan failure mode.
