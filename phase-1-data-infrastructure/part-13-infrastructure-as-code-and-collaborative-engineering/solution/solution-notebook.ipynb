# %% [markdown]
# # Solution — IaC and Collaboration

# %%
def policy(environment, deletion_protection):
    if environment=='production' and not deletion_protection:
        return {'allowed':False,'reason':'production requires deletion protection'}
    return {'allowed':True}
policy('production',False), policy('staging',False)

# %% [markdown]
# Policy sederhana menjadi contoh guardrail yang dijalankan sebelum apply.
