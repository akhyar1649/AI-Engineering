# %% [markdown]
# # Infrastructure as Code & Collaborative Engineering — PT Kirimin

# %% [markdown]
# > Diverifikasi: Terraform AWS Provider v6.62.0 — sumber: https://registry.terraform.io/providers/-/aws/latest — tanggal cek: 2026-09-18

# %%
desired={'environment':'staging','raw_bucket':'kirimin-raw-staging','database_size':'small','deletion_protection':False}
actual={'environment':'staging','raw_bucket':'kirimin-raw-staging','database_size':'medium','deletion_protection':False}
drift={key:(actual.get(key),value) for key,value in desired.items() if actual.get(key)!=value}
drift

# %% [markdown]
# ## Mini-exercise
# 1. Tambahkan policy bahwa production wajib deletion protection.
# 2. Buat checklist plan review sebelum apply.
# # TODO: tulis guardrail Anda.

# %% [markdown]
# ## Takeaway
# IaC membuat perubahan infra dapat dibaca, direview, dan diulang.
