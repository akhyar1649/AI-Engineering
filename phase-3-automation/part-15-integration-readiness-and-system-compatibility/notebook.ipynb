# %% [markdown]
# # Integration Readiness & System Compatibility — PT Kirimin

# %%
checks={'api_contract':True,'auth':True,'idempotency':False,'sandbox':True,'rate_limit':True,'owner':True}
def readiness(checks):
    blockers=[k for k,v in checks.items() if not v]
    return 'blocked' if blockers else 'ready'
readiness(checks)

# %% [markdown]
# ## Mini-exercise
# Tambahkan conditional readiness dengan owner/due date untuk non-blocker.
# # TODO: buat go/no-go record.

# %% [markdown]
# ## Takeaway
# Integration readiness membutuhkan evidence dan blocker handling, bukan score kosmetik.
