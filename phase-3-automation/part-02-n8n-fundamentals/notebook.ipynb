# %% [markdown]
# # n8n Fundamentals — PT Kirimin

# %%
workflow={'nodes':[{'name':'Webhook','type':'trigger'},{'name':'Validate','type':'transform'},{'name':'Notify','type':'action'}],'connections':[('Webhook','Validate'),('Validate','Notify')]}
workflow

# %%
def has_secret(workflow):
    text=str(workflow).lower()
    return 'api_key' in text or 'password' in text
has_secret(workflow)

# %% [markdown]
# ## Mini-exercise
# Tambahkan error branch dan credential reference placeholder.
# # TODO: lengkapi workflow contract.

# %% [markdown]
# ## Takeaway
# Workflow definition harus portable dan secret-free.
