# %% [markdown]
# # Translating Business Process to Automation Flow — PT Kirimin

# %%
steps=[('receive_event','trigger'),('validate_payload','decision'),('persist_event','action'),('notify_customer','side_effect'),('review_exception','human')]
nodes=[{'name':name,'kind':kind,'owner':'Ops' if kind!='human' else 'Support'} for name,kind in steps]
nodes

# %% [markdown]
# ## Mini-exercise
# Tambahkan system of record, SLA, failure path, dan acceptance criterion per step.
# # TODO: buat as-is/to-be comparison.

# %% [markdown]
# ## Takeaway
# Workflow yang baik berasal dari proses dan outcome bisnis yang dapat diverifikasi.
