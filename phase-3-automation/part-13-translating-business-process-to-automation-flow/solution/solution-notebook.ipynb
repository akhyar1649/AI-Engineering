# %% [markdown]
# # Solution — Process to Flow

# %%
acceptance = [
    {'criterion': 'event persisted', 'evidence': 'ledger_id'},
    {'criterion': 'notification accepted', 'evidence': 'provider_message_id'},
    {'criterion': 'failure owned', 'evidence': 'ticket_id'},
]
acceptance

# %% [markdown]
# Acceptance memakai evidence observable, bukan status node semata.
