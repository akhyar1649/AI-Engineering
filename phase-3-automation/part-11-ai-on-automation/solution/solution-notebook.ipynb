# %% [markdown]
# # Solution — AI on Automation

# %%
def safe_route(label, confidence):
    if label in {'refund','account'} or confidence<0.75: return 'human_review'
    return {'tracking':'tracking_flow','faq':'faq_flow'}.get(label,'human_review')
[(x,safe_route(*x)) for x in [('tracking',.9),('refund',.99),('faq',.6)]]

# %% [markdown]
# Risk class mengalahkan confidence tinggi untuk action sensitif.
