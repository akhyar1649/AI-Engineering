# %% [markdown]
# # Solution — Deployment TCO

# %%
def tco(runtime, db, backup, ops_hours, rate=25, outage_risk=0):
    return runtime+db+backup+ops_hours*rate+outage_risk
{'vps':tco(40,20,10,16),'managed':tco(100,50,20,4)}

# %% [markdown]
# TCO membuat ops effort dan risk terlihat dalam perbandingan.
