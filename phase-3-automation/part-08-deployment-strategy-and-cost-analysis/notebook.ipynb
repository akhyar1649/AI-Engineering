# %% [markdown]
# # Deployment Strategy & Cost Analysis — PT Kirimin

# %%
options={'cloud':{'runtime':100,'ops_hours':4,'backup':20},'vps':{'runtime':40,'ops_hours':16,'backup':10}}
engineer_rate=25
{key: value['runtime']+value['backup']+value['ops_hours']*engineer_rate for key,value in options.items()}

# %% [markdown]
# ## Mini-exercise
# Tambahkan outage cost, egress, and growth sensitivity.
# # TODO: tulis deployment decision.

# %% [markdown]
# ## Takeaway
# Deployment decision harus menghitung operasi dan recovery, bukan hanya compute.
