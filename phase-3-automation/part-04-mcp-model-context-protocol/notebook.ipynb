# %% [markdown]
# # MCP (Model Context Protocol) — PT Kirimin

# %%
capabilities=[{'name':'get_tracking','kind':'tool','side_effect':False,'scope':'shipment:read'},{'name':'refund_order','kind':'tool','side_effect':True,'scope':'finance:write'}]
def allowed(capability, approved=False):
    return not capability['side_effect'] or approved
[(c['name'],allowed(c)) for c in capabilities]

# %% [markdown]
# ## Mini-exercise
# Tambahkan auth scope, user consent, output schema, dan audit event.
# # TODO: buat capability policy.

# %% [markdown]
# ## Takeaway
# Protocol interoperability perlu disertai capability control dan approval.
