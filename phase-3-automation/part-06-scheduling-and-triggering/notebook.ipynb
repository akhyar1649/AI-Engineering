# %% [markdown]
# # Scheduling & Triggering — PT Kirimin

# %%
from datetime import datetime
def run_key(process, logical_date): return f'{process}:{logical_date}'
runs=set()
for logical_date in ['2026-09-18','2026-09-18','2026-09-19']:
    key=run_key('reconciliation',logical_date)
    if key not in runs: runs.add(key)
sorted(runs)

# %% [markdown]
# ## Mini-exercise
# Tambahkan timezone-aware datetime dan dry-run flag untuk backfill.
# # TODO: uji missed run.

# %% [markdown]
# ## Takeaway
# Trigger contract harus mendefinisikan logical time, duplicate key, dan side-effect policy.
