# %% [markdown]
# # Principles of Automation — PT Kirimin

# %%
processes=[{'name':'send_delivery_notification','volume':10000,'rule_stability':5,'risk':2,'exceptions':1},{'name':'approve_refund','volume':100,'rule_stability':2,'risk':5,'exceptions':4}]
def fit(p): return p['volume']*p['rule_stability']/(p['risk']+p['exceptions'])
[(p['name'],round(fit(p),1)) for p in processes]

# %% [markdown]
# ## Mini-exercise
# Tambahkan maintenance cost dan human review capacity.
# # TODO: buat automation canvas.

# %% [markdown]
# ## Takeaway
# Automation yang baik memilih boundary, bukan menghapus semua manusia.
