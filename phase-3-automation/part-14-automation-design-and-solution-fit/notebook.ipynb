# %% [markdown]
# # Automation Design & Solution Fit — PT Kirimin

# %%
weights={'time_to_value':.2,'reliability':.25,'security':.2,'cost':.15,'maintainability':.2}
scores={'n8n':{'time_to_value':5,'reliability':3,'security':3,'cost':4,'maintainability':4},'custom':{'time_to_value':2,'reliability':4,'security':4,'cost':2,'maintainability':3}}
{option:sum(weights[k]*values[k] for k in weights) for option,values in scores.items()}

# %% [markdown]
# ## Mini-exercise
# Ubah bobot jika workflow menyentuh finance dan jelaskan perubahan ranking.
# # TODO: tulis ADR.

# %% [markdown]
# ## Takeaway
# Tool fit harus mengikuti weighted business/technical requirement.
