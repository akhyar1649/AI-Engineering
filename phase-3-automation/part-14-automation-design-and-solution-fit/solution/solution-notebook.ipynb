# %% [markdown]
# # Solution — Solution Fit

# %%
def score(option, weights): return sum(option[k]*weights[k] for k in weights)
n8n={'reliability':3,'security':3,'cost':4}; weights={'reliability':.4,'security':.4,'cost':.2}
score(n8n,weights)

# %% [markdown]
# Bobot security/reliability dapat mengubah keputusan ketika workflow menyentuh finance.
