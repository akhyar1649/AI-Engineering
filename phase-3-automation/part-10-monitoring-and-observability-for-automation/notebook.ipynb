# %% [markdown]
# # Monitoring & Observability for Automation — PT Kirimin

# %%
runs=[{'status':'success','duration':2,'retries':0,'dlq':0},{'status':'failed','duration':8,'retries':2,'dlq':1},{'status':'success','duration':3,'retries':1,'dlq':0}]
success=sum(r['status']=='success' for r in runs)/len(runs)
retry_rate=sum(r['retries']>0 for r in runs)/len(runs)
{'success_rate':success,'retry_rate':retry_rate,'dlq_count':sum(r['dlq'] for r in runs)}

# %% [markdown]
# ## Mini-exercise
# Tambahkan p95 duration, correlation id, PII redaction, dan alert ownership.
# # TODO: tulis dashboard spec.

# %% [markdown]
# ## Takeaway
# Observability membuat workflow dapat dijelaskan dari trigger sampai side effect.
