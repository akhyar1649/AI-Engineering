# %% [markdown]
# # Self-Hosted Infrastructure Setup — PT Kirimin

# %%
checklist={'tls':True,'firewall':True,'non_root':True,'backup_tested':False,'secret_outside_workflow':True}
failed=[key for key,value in checklist.items() if not value]
{'status':'ready' if not failed else 'blocked','failed':failed}

# %% [markdown]
# ## Mini-exercise
# Tambahkan RPO/RTO dan evidence path untuk setiap check.
# # TODO: tulis restore test.

# %% [markdown]
# ## Takeaway
# Self-hosting adalah tanggung jawab operasi penuh; checklist harus punya evidence.
