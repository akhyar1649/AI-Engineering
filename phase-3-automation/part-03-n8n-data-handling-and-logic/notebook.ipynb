# %% [markdown]
# # n8n Data Handling & Logic — PT Kirimin

# %%
events=[{'event_id':'E-1','status':'delivered'},{'event_id':'E-1','status':'delivered'},{'event_id':'E-2','status':'failed'}]
seen=set(); results=[]
for event in events:
    if event['event_id'] in seen: continue
    seen.add(event['event_id'])
    results.append({'event':event,'branch':'notify' if event['status']=='delivered' else 'exception'})
results

# %% [markdown]
# ## Mini-exercise
# Tambahkan pagination guard dan merge dengan customer channel.
# # TODO: uji duplicate dan missing field.

# %% [markdown]
# ## Takeaway
# Data handling yang eksplisit mencegah item hilang atau side effect ganda.
